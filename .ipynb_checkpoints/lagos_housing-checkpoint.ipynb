# %% [markdown]
# # Predicting Price Of Renting An Apartment In Lagos State.

# %% [markdown]
# The objective of this project is predicting the cost of renting an apartment in lagos state based on the area, number of bed rooms and number of toilets.
# Data set for this project was gathered from https://tolet.ng, also scrapper for gathered the data can be found on my github here -> https://github.com/victorlenerd/toletngscrapper.

# %% [markdown]
# ## Loading And Cleaning Data.

# %%
## Loading Data
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import sklearn.metrics as sm
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
import math
import re


sns.set_style("whitegrid")

# %matplotlib inline
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_json('./data.all.json')
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17214 entries, 0 to 17213
# Data columns (total 8 columns):
# address              17214 non-null object
# lat                  17213 non-null float64
# lng                  17213 non-null float64
# no_bath              17212 non-null object
# no_bed               17214 non-null object
# no_parking_spaces    7185 non-null float64
# no_toilets           17213 non-null object
# price                17070 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                 lat            lng  no_parking_spaces         price
# count  17213.000000   17213.000000        7185.000000  1.707000e+04
# mean       6.511095     305.599635          10.058733  2.740115e+06
# std        0.070590   10991.660177         213.872935  5.470854e+07
# min        6.409760       2.887644           0.000000  1.000000e-02
# 25%        6.451514       3.360304           0.000000  5.000000e+05
# 50%        6.500500       3.421944           1.000000  1.000000e+06
# 75%        6.564985       3.469745           3.000000  2.000000e+06
# max        7.539378  400106.000000       12345.000000  5.000000e+09

# %%
df = df.drop('address', axis=1)

# %%
def clean_bed(bed):
        try:
            return int(bed)
        except ValueError:
            return 0
        except TypeError:
            return bed

df['no_bed'] = df['no_bed'].apply(clean_bed)
df['no_bath'] = df['no_bath'].apply(clean_bed)
df['no_toilets'] = df['no_toilets'].apply(clean_bed)
df['no_parking_spaces'] = df['no_parking_spaces'].apply(clean_bed)

# %%
df = df[df['no_bed'] > 1]
df = df[df['no_bath'] > 1]
df = df[df['no_toilets'] > 1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12257 entries, 0 to 17213
# Data columns (total 7 columns):
# lat                  12256 non-null float64
# lng                  12256 non-null float64
# no_bath              12257 non-null float64
# no_bed               12257 non-null int64
# no_parking_spaces    12257 non-null int64
# no_toilets           12257 non-null float64
# price                12143 non-null float64
# dtypes: float64(5), int64(2)
# memory usage: 766.1 KB

# %%
df['no_bath'].replace('', np.nan, inplace=True)
df['no_bed'].replace('', np.nan, inplace=True)
df['no_toilets'].replace('', np.nan, inplace=True)
df['no_parking_spaces'].replace('', np.nan, inplace=True)
df['price'].replace('', np.nan, inplace=True)

def get_number_from_string(my_str):
    if type(my_str) == str: 
        numstr = re.findall('\d+', my_str)
    
        if len(numstr) < 1:
            return 0
    
        return int(numstr[0])
    
    return my_str
    
df['no_toilets'] = df['no_toilets'].apply(get_number_from_string)

df = df[np.isfinite(df['price'])]
df = df[np.isfinite(df['no_toilets'])]
df = df[np.isfinite(df['no_bed'])]
df = df[np.isfinite(df['no_bath'])]
df = df[np.isfinite(df['no_parking_spaces'])]

df['no_bed'] = df['no_bed'].astype(int)
df['no_bath'] = df['no_bath'].astype(int)
df['no_toilets'] = df['no_toilets'].astype(int)
df['no_parking_spaces'] = df['no_parking_spaces'].astype(int)

# %%
df
# Out:
#                   area no_bath no_bed no_parking_spaces no_toilets       price
# 0                Isolo       2      3                 0          3    600000.0
# 1                Ikeja       2      2                 0          2   1000000.0
# 2               Oshodi       1      1                 0          2    230000.0
# 3               Oshodi       1      2                 0          1    600000.0
# 4               Oshodi       2      2                 0          2    600000.0
# 5                Lekki       2      3                 0          3   1200000.0
# 6               Oshodi       1      0                 0          2    320000.0
# 7               Oshodi       1      2                 0          1    350000.0
# 8                 Ajah       1      1                 0          1    250000.0
# 9                 Ajah       3      3                 0          4    750000.0
# 10                Ajah       2      2                 0          3    450000.0
# 11                Ajah       2      2                 0          3    500000.0
# 12         Ibeju Lekki       3      3                 0          4    350000.0
# 13                Ajah       2      2                 0          3    650000.0
# 14                Ajah       1      1                 0          1    270000.0
# 15                Ajah       2      2                 0          3    400000.0
# 16            Alimosho       3      3                 0          3    200000.0
# 17               Isolo       3      3                 0          3    750000.0
# 18               Okota       1      2                 0          2    500000.0
# 19                 Ojo       2      3                 0          3    600000.0
# 20               Lekki       4      4                 0          4   3000000.0
# 21         Ibeju Lekki       3      3                 0          3    600000.0
# 22               Lekki       3      3                 0          4   2000000.0
# 23              Magodo       2      3                 0          3    900000.0
# 24               Isolo       2      2                 0          2    400000.0
# 25              Kosofe       3      3                 0          3   2000000.0
# 26               Ikoyi       4      4                 0          5  15000000.0
# 27            Alimosho       3      3                 0          3    900000.0
# 28                 Ojo       2      2                 0          3    400000.0
# 29            Alimosho       3      3                 0          3    250000.0
# ...                ...     ...    ...               ...        ...         ...
# 17286            Ikeja       3      3               NaN          4   1200000.0
# 17287            Ikeja       1      1               NaN          2    850000.0
# 17288            Lekki       3      3               NaN          4   4500000.0
# 17289            Ikeja       2      2               NaN          2    750000.0
# 17290            Ikoyi       3      3               NaN          4  14000000.0
# 17291            Isolo       1      1                 1          1    200000.0
# 17292            Isolo       2      1               NaN          2    300000.0
# 17293            Isolo       2      2                 2          2    500000.0
# 17294            Ikeja       1      1               NaN          1    550000.0
# 17295  Victoria Island     NaN    NaN               NaN        NaN   6000000.0
# 17296            Ikeja       3      3               NaN          4    800000.0
# 17297            Ikeja       2      2               NaN          2    600000.0
# 17298            Lekki       3      3                 3          4   3500000.0
# 17299      Ibeju Lekki       2      3               NaN          3    500000.0
# 17301            Ikeja       2      3               NaN          3    600000.0
# 17302            Ikeja       2      2               NaN          2    600000.0
# 17303              Ojo       3      3               NaN          4    900000.0
# 17304            Ikeja       2      2               NaN          2    800000.0
# 17305            Ikeja       1      1               NaN          2    350000.0
# 17306           Ijaiye       2      3               NaN          2    650000.0
# 17307            Ikeja       3      3               NaN          4   1200000.0
# 17308            Ikeja       3      3               NaN          4    850000.0
# 17310            Ikoyi       5      4               NaN        NaN  22000000.0
# 17311            Ikeja       2      3                 2          3    850000.0
# 17312            Lekki       3      3                 2          4   2500000.0
# 17313            Ikeja       3      3               NaN          4    700000.0
# 17315            Lekki       4      3                 2          4   2000000.0
# 17316            Lekki       2      1                 2          2   1300000.0
# 17318            Ikeja     NaN      1               NaN        NaN    200000.0
# 17319            Ikeja       2      3               NaN          3    600000.0
#
# [17157 rows x 6 columns]

# %%
print(df.describe())
print(df.info())
# Out:
#             no_bath       no_bed  no_parking_spaces   no_toilets         price
# count   3868.000000  3868.000000        3868.000000  3868.000000  3.763000e+03
# mean      13.916753     2.464064          10.449586     3.472079  5.730494e+06
# std      707.432370     1.053275          70.320617    13.627369  1.152603e+08
# min        1.000000     1.000000           1.000000     1.000000  1.000000e+00
# 25%        2.000000     2.000000           2.000000     2.000000  9.000000e+05
# 50%        3.000000     3.000000           2.000000     4.000000  1.800000e+06
# 75%        3.000000     3.000000           4.000000     4.000000  3.500000e+06
# max    44000.000000    34.000000        2000.000000   600.000000  5.000000e+09
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3868 entries, 9840 to 17316
# Data columns (total 6 columns):
# area                 3868 non-null object
# no_bath              3868 non-null int64
# no_bed               3868 non-null int64
# no_parking_spaces    3868 non-null int64
# no_toilets           3868 non-null int64
# price                3763 non-null float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 211.5+ KB
# None

# %% [markdown]
# ### Visualizing Data

# %%
plt.figure(figsize=(10,8))

low = np.min(data['price'])
high = np.max(data['price'])

plt.subplot(2, 2, 1)
plt.scatter(x=data['no_bed'], y=data['price'], color='blue')
plt.title('Price per Bed Rooms')
plt.xlabel('No Of Bed Rooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 2)
plt.scatter(data['no_toilets'], data['price'], color='red')
plt.title('Price per Toilets')
plt.xlabel('No Of Toilets')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 3)
plt.scatter(data['no_bath'], data['price'], color='green')
plt.title('Price per Toilets')
plt.xlabel('No Of Bathrooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.tight_layout()
plt.show()

# %%
low = np.min(data['price'])
high = np.max(data['price'])
sp = sns.stripplot(x=data["no_bed"], y=data["price"], jitter=True)
sp.set_ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
# Out:
# (-174999999.0, 525000000.0)

# %% [markdown]
# ### Dealing with ouliers

# %% [markdown]
# Some entries in the data are hostels, office spaces and shops. They have to be removed because this project is only focused on apartments.

# %%
less_than_one_bed = df[data['no_bath'] < 6]
less_than_one_bed
# Out:
#       area  no_bath  no_bed  no_toilets       price
# 0        2        3       3           4   1200000.0
# 6       26        5       5           5   4000000.0
# 8       21        2       2           0    200000.0
# 9       21        3       3           0   5500000.0
# 10      38        3       3           4  18000000.0
# 11      38        1       3           2     50000.0
# 12       2        3       3           4    550000.0
# 13       2        3       3           4   1500000.0
# 14      38        4       4           5   6000000.0
# 15      38        3       3           4   5000000.0
# 16       4        3       3           0  13000000.0
# 18      38        3       3           4   2700000.0
# 23      38        3       3           4   4500000.0
# 24      26        3       3           4   3000000.0
# 25      26        4       4           5   7000000.0
# 26      26        3       3           4   3500000.0
# 27      26        4       4           5   3000000.0
# 28      38        2       2           3   5000000.0
# 30      38        3       3           4   2500000.0
# 31      18        3       3           4     60000.0
# 32      18        4       4           5     70000.0
# 33      12        3       3           4   1500000.0
# 34      18        2       2           3   7500000.0
# 35      18        4       4           5  10000000.0
# 36      18        3       3           4  11000000.0
# 37      18        3       3           4  15000000.0
# 38      26        4       4           5   2500000.0
# 39      26        3       3           3   1500000.0
# 40      26        5       5           6   4500000.0
# 41      26        3       3           4   1600000.0
# ...    ...      ...     ...         ...         ...
# 8991    12        1       2           2    700000.0
# 8992    29        2       3           3    430000.0
# 8994    32        1       2           1    400000.0
# 8995    26        3       3           4   2800000.0
# 8997    37        2       2           3    600000.0
# 9001    29        2       2           2    700000.0
# 9002    26        4       4           5   4500000.0
# 9004     2        3       3           4   1500000.0
# 9005    26        3       3           4   3500000.0
# 9007    36        1       3           2    900000.0
# 9008    34        2       3           2    700000.0
# 9012    23        0       2           0    500000.0
# 9013    23        0       2           0    550000.0
# 9014    26        3       2           3   3500000.0
# 9015    32        3       4           3   1000000.0
# 9018    29        2       2           2    600000.0
# 9019    26        3       3           4   7000000.0
# 9020    21        3       2           3    250000.0
# 9025    26        4       4           5   4500000.0
# 9026    26        5       5           6   5000000.0
# 9028    37        3       3           4   1600000.0
# 9029     0        2       2           2    350000.0
# 9031    26        3       3           4   2500000.0
# 9032    26        4       4           5   2500000.0
# 9035     2        2       2           3    550000.0
# 9036    26        5       4           5   5500000.0
# 9037    15        3       3           4   1500000.0
# 9038     0        2       2           3    500000.0
# 9039    26        5       5           6   5500000.0
# 9040    15        5       5           6   2500000.0
#
# [5747 rows x 5 columns]

# %% [markdown]
# ### Convert Area To Numerical Values

# %%
encoder = LabelEncoder()
housing_areas = df['area']
housing_area_endcoded = encoder.fit_transform(housing_areas)
df['area'] = housing_area_endcoded

# %%
encoder.classes_
# Out:
# array([u'Abule Egba', u'Agege', u'Ajah', u'Alimosho', u'Amuwo Odofin',
#        u'Apapa', u'Atlantic City', u'Badagry', u'Ebute Metta', u'Ejigbo',
#        u'Epe', u'Gbagada', u'Ibeju Lekki', u'Idi Araba', u'Idimu',
#        u'Iganmu', u'Ijaiye', u'Ijesha', u'Ikeja', u'Ikorodu', u'Ikotun',
#        u'Ikoyi', u'Ilaje', u'Ilupeju', u'Ipaja', u'Isheri', u'Isolo',
#        u'Ketu', u'Kosofe', u'Lagos Island', u'Lekki', u'Magodo',
#        u'Maryland', u'Ogba', u'Ogudu', u'Ojo', u'OkeOdo', u'Oshodi',
#        u'Shomolu', u'Surulere', u'Victoria Island', u'Yaba'], dtype=object)

# %%
df.head()
# Out:
#       area  no_bath  no_bed  no_parking_spaces  no_toilets      price
# 9840    30        1       1                  1           2  2000000.0
# 9841    30        3       3                  2           4  3000000.0
# 9842    30        2       2                  2           3  1500000.0
# 9843    40        3       3                  2           4  2500000.0
# 9844    30        1       1                  1           1  1500000.0

# %% [markdown]
# # Model Development

# %% [markdown]
# The accuracy of the model used would be measured using:
#    * **Mean Squared Error**: This is the average of the squares of the errors of all the datapoints in the given dataset.
#    * **Explained Variance Score**: This score measures how well our model can account for the variation in our dataset.
#    * **R2-score**: This tells us how well the unknown samples will be predicted by our model.

# %%
def accuracy(test, pred):
    print("Mean Squared Error: ", round(sm.mean_squared_error(test, pred), 2))
    print("Explained Variance Score: ", round(sm.explained_variance_score(test, pred),2))
    print("R2-score: ", round(sm.r2_score(test, pred), 2))

# %% [markdown]
# ## Spliting data for train and test

# %%
price = pd.Series(df['price'], dtype='float32')
feature_final = df.drop('price', axis=1)

X_train, X_test, y_train, y_test = train_test_split(feature_final,
                                                    price,
                                                   test_size = 0.2,
                                                   random_state = 0)

# %%
print("Training set has {} samples.", X_train.shape)
print("Testing set has {} samples.", y_train.shape)
# Out:
# ('Training set has {} samples.', (3094, 5))
# ('Testing set has {} samples.', (3094,))

# %% [markdown]
# ### Base Model Performance

# %%
linear_regressor = linear_model.LinearRegression()
linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_train_pred = linear_regressor.predict(X_test)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-30-c434da88acfa> in <module>()
# ----> 1 y_train_pred = linear_regressor.predict(X_test)
#
# NameError: name 'linear_regressor' is not defined

# %%
accuracy(y_train, y_train_pred)
# Out:
# Mean Squared Error:  3.41036835367e+15
# Explained Variance Score:  0.01
# R2-score:  0.01
