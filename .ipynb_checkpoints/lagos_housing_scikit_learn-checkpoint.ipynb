# %% [markdown]
# # Predicting Price Of Renting An Apartment In Lagos State.

# %% [markdown]
# The objective of this project is predicting the cost of renting an apartment in lagos state based on the area, number of bed rooms and number of toilets.
# Data set for this project was gathered from https://propertypro.ng and https://nigerianpropertycenter.ng, also scrapper for gathered the data can be found on my github here -> https://github.com/victorlenerd/toletngscrapper.

# %% [markdown]
# ## Loading And Cleaning Data.

# %%
## Loading Data
import math
import seaborn as sns
import sklearn.metrics as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from time import time
from pandas.tools.plotting import scatter_matrix
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import make_scorer
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
import pickle
from sklearn.externals import joblib

sns.set_style("whitegrid")

# %matplotlib inline

# %%
df = pd.read_json('./data.all.json')
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14443 entries, 0 to 17832
# Data columns (total 7 columns):
# address       14443 non-null object
# lat           14440 non-null float64
# lng           14440 non-null float64
# no_bath       14442 non-null float64
# no_bed        14443 non-null int64
# no_toilets    14442 non-null float64
# price         14338 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 902.7+ KB

# %%
df.describe()
# Out:
#                 lat            lng       no_bath       no_bed    no_toilets  \
# count  14440.000000   14440.000000  14442.000000  14443.00000  14442.000000
# mean       6.518184     751.506743      5.461847      2.32791      2.851752
# std        0.456430   17285.355056    366.202732      0.94829     10.840266
# min        6.409760    -122.271114      0.000000      0.00000      0.000000
# 25%        6.451514       3.353170      2.000000      2.00000      2.000000
# 50%        6.499078       3.400106      2.000000      3.00000      3.000000
# 75%        6.574911       3.469745      3.000000      3.00000      4.000000
# max       37.804364  400106.000000  44000.000000     13.00000    700.000000
#
#               price
# count  1.433800e+04
# mean   2.177509e+06
# std    8.864966e+06
# min    1.000000e-02
# 25%    5.000000e+05
# 50%    1.000000e+06
# 75%    2.000000e+06
# max    8.500000e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14443 entries, 0 to 17832
# Data columns (total 7 columns):
# address       14443 non-null object
# lat           14440 non-null float64
# lng           14440 non-null float64
# no_bath       14442 non-null float64
# no_bed        14443 non-null int64
# no_toilets    14442 non-null float64
# price         14338 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 902.7+ KB

# %%
df.head()
# Out:
#                                              address       lat       lng  \
# 0               unity homes thomas estate ajah lagos  6.470383  3.567407
# 1                dopemu road akowonjo alimosho lagos  6.583560  3.293578
# 2  179 dopemu road,lagos,nigeria akowonjo alimosh...  6.583560  3.293578
# 3           estate apple junction amuwo odofin lagos  6.453094  3.291062
# 4  ago - amuwo link bridge estate ago palace okot...  6.500235  3.302859
#
#    no_bath  no_bed  no_toilets      price
# 0      4.0       3         3.0  1000000.0
# 1      1.0       1         2.0   250000.0
# 2      1.0       1         1.0   170000.0
# 3      2.0       2         3.0  1000000.0
# 4      2.0       3         2.0  1000000.0

# %%
def clean_nums(num):
    try:
        return int(num)
    except ValueError:
        return 0
    except TypeError:
        return num

df['no_bed'] = df['no_bed'].apply(clean_nums)
df['no_bath'] = df['no_bath'].apply(clean_nums)
df['no_toilets'] = df['no_toilets'].apply(clean_nums)

# %%
df = df.drop('address', axis=1)

# %%
df = df[df['no_bed'] >= 1]
# df = df[df['no_bed'] <= 10]

df = df[df['no_bath'] >= 1]
# df = df[df['no_bath'] <= 10]

df = df[df['no_toilets'] >= 1]
# df = df[df['no_toilets'] <= 11]

# %%
df = df[np.isfinite(df['price'])]

# %%
df.head()
# Out:
#                                              address       lat       lng  \
# 0               unity homes thomas estate ajah lagos  6.470383  3.567407
# 1                dopemu road akowonjo alimosho lagos  6.583560  3.293578
# 2  179 dopemu road,lagos,nigeria akowonjo alimosh...  6.583560  3.293578
# 3           estate apple junction amuwo odofin lagos  6.453094  3.291062
# 4  ago - amuwo link bridge estate ago palace okot...  6.500235  3.302859
#
#    no_bath  no_bed  no_toilets      price
# 0        4       3           3  1000000.0
# 1        1       1           2   250000.0
# 2        1       1           1   170000.0
# 3        2       2           3  1000000.0
# 4        2       3           2  1000000.0

# %%
df = df.dropna()
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#                 lat            lng       no_bath        no_bed    no_toilets  \
# count  13172.000000   13172.000000  13172.000000  13172.000000  13172.000000
# mean       6.516781     732.404928      2.409125      2.371849      3.089356
# std        0.391874   17063.637203      0.981347      0.874507     11.317425
# min        6.409760    -122.271114      1.000000      1.000000      1.000000
# 25%        6.451514       3.353170      2.000000      2.000000      2.000000
# 50%        6.499078       3.391811      3.000000      3.000000      3.000000
# 75%        6.574900       3.469745      3.000000      3.000000      4.000000
# max       37.804364  400106.000000     31.000000     13.000000    700.000000
#
#               price
# count  1.317200e+04
# mean   2.064886e+06
# std    8.323162e+06
# min    1.200000e+00
# 25%    5.000000e+05
# 50%    1.000000e+06
# 75%    2.000000e+06
# max    8.500000e+08

# %% [markdown]
# ### Visualizing Data

# %%
plt.figure(figsize=(10,8))

low = np.min(df['price'])
high = np.max(df['price'])

plt.subplot(2, 2, 1)
plt.scatter(x=df['no_bed'], y=df['price'], color='blue')
plt.title('Price per Bed Rooms')
plt.xlabel('No Of Bed Rooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 2)
plt.scatter(df['no_toilets'], df['price'], color='red')
plt.title('Price per Toilets')
plt.xlabel('No Of Toilets')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 3)
plt.scatter(df['no_bath'], df['price'], color='green')
plt.title('Price per Toilets')
plt.xlabel('No Of Bathrooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treating Outliers

# %%
df['price'] = df['price'].astype('int')
df[df['price'] > 1000000000]
# Out:
# Empty DataFrame
# Columns: [address, lat, lng, no_bath, no_bed, no_toilets, price]
# Index: []

# %%
df = df[df['price'] < 1000000000]

# %%
plt.figure(figsize=(10,8))

low = np.min(df['price'])
high = np.max(df['price'])

plt.subplot(2, 2, 1)
plt.scatter(x=df['no_bed'], y=df['price'], color='blue')
plt.title('Price per Bed Rooms')
plt.xlabel('No Of Bed Rooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 2)
plt.scatter(df['no_toilets'], df['price'], color='red')
plt.title('Price per Toilets')
plt.xlabel('No Of Toilets')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.subplot(2, 2, 3)
plt.scatter(df['no_bath'], df['price'], color='green')
plt.title('Price per Toilets')
plt.xlabel('No Of Bathrooms')
plt.ylabel('Price')
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])

plt.tight_layout()
plt.show()

# %%
df[df['lng'] == 3.3490]
# Out:
#           lat    lng  no_bath  no_bed  no_toilets   price
# 4794   6.4926  3.349        1       2           1  500000
# 4797   6.4926  3.349        2       3           2  800000
# 12002  6.4926  3.349        2       3           2  800000

# %% [markdown]
# # Model Development

# %% [markdown]
# The accuracy of the model used would be measured using:
#    * **Mean Squared Error**: This is the average of the squares of the errors of all the datapoints in the given dataset.
#    * **Explained Variance Score**: This score measures how well our model can account for the variation in our dataset.
#    * **R2-score**: This tells us how well the unknown samples will be predicted by our model.

# %%
def accuracy(test, pred, log = False):
    acc = {
        'mse': round(sm.mean_squared_error(test, pred), 2),
        'r2_score': round(sm.r2_score(test, pred), 2)
    }
    
    if log is True:
        print("Mean Squared Error: ", acc['mse'])
        print("R2-score: ", acc['r2_score'])
    else:
        return acc

# %% [markdown]
# ## Spliting data for train and test

# %%
price = pd.Series(df['price'], dtype='float32')
feature_final = df.drop('price', axis=1)

X_train, X_test, y_train, y_test = train_test_split(feature_final,
                                                    price,
                                                    test_size = 0.2,
                                                    random_state = 1)

# %%
print("Training set has {} samples.", X_train.shape)
print("Testing set has {} samples.", y_train.shape)
# Out:
# Training set has {} samples. (10537, 5)
# Testing set has {} samples. (10537,)

# %% [markdown]
# ### Base Model Performance

# %%
linear_regressor = linear_model.LinearRegression()
linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_train_pred = linear_regressor.predict(X_train)

# %%
accuracy(y_train, y_train_pred, True)
# Out:
# Mean Squared Error:  8.17120381844e+13
# R2-score:  0.01

# %%
y_test_pred = linear_regressor.predict(X_test)

# %%
accuracy(y_test, y_test_pred, True)
# Out:
# Mean Squared Error:  1.3591810057e+13
# R2-score:  0.09

# %% [markdown]
# ### Best Model Performance

# %%
def train_predict(learner, sample_size, X_train, y_train, X_test, y_test):
    results = {}
    start = time()    
    learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time()
    results['train_time'] = end - start
    
    start = time()
    prediction_test = learner.predict(X_test)
    prediction_train = learner.predict(X_train[:100])
    end = time()
    
    acc_train = accuracy(prediction_train[:100], y_train[:100])
    acc_test = accuracy(prediction_test[:100], y_test[:100])
    
    results['pred_time'] = end - start
    results['r2_score_train'] = acc_train['r2_score']
    results['mse_train'] = acc_train['mse']
    results['r2_score_test'] = acc_test['r2_score']
    results['mse_test'] = acc_test['mse']

    print(learner.__class__.__name__, "trained on", sample_size, "samples.")
    
    return results

# %%
samples_100 = len(y_train)
samples_10 = int(math.floor((samples_100 * 10) / 100))
samples_1 = int(math.floor((samples_100 * 1) / 100))

# %%
clf_a = linear_model.Ridge()
clf_b = SVR()
clf_c = DecisionTreeRegressor()
clf_d = RandomForestRegressor()
clf_f = BaggingRegressor()

# %%
results = {}
for clf in [clf_a, clf_b, clf_c, clf_d, clf_f]:
    clf_name = clf.__class__.__name__
    results[clf_name] = {}
    for i, samples in enumerate([samples_1, samples_10, samples_100]):
        results[clf_name][i] = \
        train_predict(clf, samples, X_train, y_train, X_test, y_test)
# Out:
# Ridge trained on 105 samples.
# Ridge trained on 1053 samples.
# Ridge trained on 10537 samples.
# SVR trained on 105 samples.
# SVR trained on 1053 samples.
# SVR trained on 10537 samples.
# DecisionTreeRegressor trained on 105 samples.
# DecisionTreeRegressor trained on 1053 samples.
# DecisionTreeRegressor trained on 10537 samples.
# RandomForestRegressor trained on 105 samples.
# RandomForestRegressor trained on 1053 samples.
# RandomForestRegressor trained on 10537 samples.
# BaggingRegressor trained on 105 samples.
# BaggingRegressor trained on 1053 samples.
# BaggingRegressor trained on 10537 samples.

# %%
print("DecisionTreeRegressor_MSE_TEST = ", results['DecisionTreeRegressor'][2]['mse_test'])
print("RandomForestRegressor_MSE_TEST = ",results['RandomForestRegressor'][2]['mse_test'])
print("Ridge_MSE_TEST = ",results['Ridge'][2]['mse_test'])
print("SVR_MSE_TEST = ",results['SVR'][2]['mse_test'])
print("BaggingRegressor_MSE_TEST = ",results['BaggingRegressor'][2]['mse_test'])
# Out:
# DecisionTreeRegressor_MSE_TEST =  2.11001533661e+12
# RandomForestRegressor_MSE_TEST =  1.15420455437e+12
# Ridge_MSE_TEST =  3.15699489255e+12
# SVR_MSE_TEST =  3.82381875704e+12
# BaggingRegressor_MSE_TEST =  1.08015970426e+12

# %%
print("DecisionTreeRegressor_MSE_TRAIN = ", results['DecisionTreeRegressor'][2]['mse_train'])
print("RandomForestRegressor_MSE_TRAIN = ",results['RandomForestRegressor'][2]['mse_train'])
print("Ridge_MSE_TRAIN = ",results['Ridge'][2]['mse_train'])
print("SVR_MSE_TRAIN = ",results['SVR'][2]['mse_train'])
print("BaggingRegressor_MSE_TRAIN = ",results['BaggingRegressor'][2]['mse_train'])
# Out:
# DecisionTreeRegressor_MSE_TRAIN =  1.21144355239e+12
# RandomForestRegressor_MSE_TRAIN =  1.26601681244e+12
# Ridge_MSE_TRAIN =  3.66424695554e+12
# SVR_MSE_TRAIN =  4.3373144913e+12
# BaggingRegressor_MSE_TRAIN =  1.1716594586e+12

# %% [markdown]
# ### Best Parameters For Best Model

# %%
def performance_metric(y_true, y_predict):
    return sm.r2_score(y_true, y_predict)

clf = DecisionTreeRegressor()

parameters = { 'max_depth': range(2, 100) } 
scorer = make_scorer(performance_metric)
grid_obj = GridSearchCV(clf, param_grid=parameters, scoring=scorer)
grid_fit = grid_obj.fit(X_train, y_train)
best_clf = grid_fit.best_estimator_

predictions = (clf.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

print("Unoptimized model", accuracy(predictions, y_test))
print("Optimized model", accuracy(best_predictions, y_test))
# Out:
# Unoptimized model {'mse': 9477030791394.7305, 'r2_score': -0.41999999999999998}
# Optimized model {'mse': 9459051439252.4805, 'r2_score': -0.64000000000000001}

# %%
best_clf
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=6, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
clf_main = BaggingRegressor(DecisionTreeRegressor(criterion='mse', max_depth=4, splitter='best'), n_estimators=500, max_samples=1.0, n_jobs=-1, bootstrap=True)

predictions = (clf_main.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

print("Bagged Optimized", accuracy(predictions, y_test))
print("Optimized model", accuracy(best_predictions, y_test))
# Out:
# Bagged Optimized {'mse': 38570687682617.523, 'r2_score': -0.16}
# Optimized model {'mse': 9459051439252.4805, 'r2_score': -0.64000000000000001}

# %% [markdown]
# ## Final Model

# %%
model = clf_main

# %%
df.head(n=15)
# Out:
#          lat       lng  no_bath  no_bed  no_toilets    price
# 0   6.470383  3.567407        4       3           3  1000000
# 1   6.583560  3.293578        1       1           2   250000
# 2   6.583560  3.293578        1       1           1   170000
# 3   6.453094  3.291062        2       2           3  1000000
# 4   6.500235  3.302859        2       3           2  1000000
# 5   6.437805  3.516615        2       2           3  1300000
# 6   6.564985  3.280998        1       1           1   250000
# 7   6.463783  3.128609        3       3           3  1600000
# 8   6.463783  3.128609        2       2           2  1800000
# 9   6.600680  3.383047        2       2           3   550000
# 10  6.600680  3.383047        3       3           3   450000
# 11  6.600680  3.383047        2       3           3   500000
# 12  6.600680  3.383047        3       3           4  1800000
# 13  6.600680  3.383047        1       1           1   350000
# 14  6.600680  3.383047        2       3           2   700000

# %%
sample = df[0:15].drop('price', axis=1)
sample
# Out:
#          lat       lng  no_bath  no_bed  no_toilets
# 0   6.470383  3.567407        4       3           3
# 1   6.583560  3.293578        1       1           2
# 2   6.583560  3.293578        1       1           1
# 3   6.453094  3.291062        2       2           3
# 4   6.500235  3.302859        2       3           2
# 5   6.437805  3.516615        2       2           3
# 6   6.564985  3.280998        1       1           1
# 7   6.463783  3.128609        3       3           3
# 8   6.463783  3.128609        2       2           2
# 9   6.600680  3.383047        2       2           3
# 10  6.600680  3.383047        3       3           3
# 11  6.600680  3.383047        2       3           3
# 12  6.600680  3.383047        3       3           4
# 13  6.600680  3.383047        1       1           1
# 14  6.600680  3.383047        2       3           2

# %%
sample_predict = model.predict(sample)

# %%
sample_predict
# Out:
# array([ 1185559.29797361,   416653.41376804,   373827.06475408,
#         2969568.38793769,   689633.41164658,  1665139.84253748,
#          373827.06475408,  2958604.65378669,  2829284.8704491 ,
#          833336.63115784,  1168477.51821788,  1163662.05223709,
#         1377099.2601926 ,   375281.25451434,  1056670.9279173 ])

# %%
lekki = pd.DataFrame({ 'lng': [6.4698], 'lat': [3.5852], 'no_bed': [1], 'no_toilets': [1], 'no_bath': [1] })

# %%
lekki_predict = model.predict(lekki)

# %%
lekki_predict
# Out:
# array([ 1222011.88505683])

# %% [markdown]
# ## Save Model

# %%
import os

# %%
s = pickle.dump(clf_main, open(os.path.join('./', 'model.pkl'), 'wb'), protocol=2)

# %%
loded_model = pickle.load(open('./model.pkl', 'rb'))

# %%
loded_model.predict(lekki)
# Out:
# array([ 1222011.88505683])

# %% [markdown]
# ## Higher and Lower Bound Price Discovery

# %%
areas_df = pd.read_json('./areas.json')

# %%
areas_df
# Out:
#          lat            lng             name
# 0   6.650300       3.286000       Abule Egba
# 1   6.528610       3.135309    Agbara-Igbesa
# 2   6.615356       3.323782            Agege
# 3   6.472516       3.568616             Ajah
# 4   7.558791       6.601780         Ajaokuta
# 5   6.658440       3.263392         Alagbado
# 6   6.546609       3.238251         Alimosho
# 7   6.524379       3.379206     Amuwo Odofin
# 8   6.444641       3.364084            Apapa
# 9   6.444116       3.372984    Atlantic City
# 10  6.431581       2.887644          Badagry
# 11  6.484464       3.376685      Ebute Metta
# 12  6.564985       3.280998       Egbe Idimu
# 13  6.591574       3.291062           Egbeda
# 14  6.551580       3.293578           Ejigbo
# 15  6.594595       3.977639              Epe
# 16  6.561638       3.384247          Gbagada
# 17  6.623306       3.331337           Ijaiye
# 18  6.570825       3.596457            Ijede
# 19  6.496267       3.596457      Ibeju Lekki
# 20  6.517865       3.357785        Idi Araba
# 21  6.583887       3.243278            Idimu
# 22  6.484631       3.351486           Iganmu
# 23  6.649740       3.323318              Iju
# 24  6.623306       3.331337           Ijaiye
# 25  6.601838       3.351486            Ikeja
# 26  6.619413       3.510454          Ikorodu
# 27  6.562564       3.243278           Ikotun
# 28  6.562564       3.243278    Ikotun Igando
# 29  6.450000       3.433333            Ikoyi
# 30  6.531235       3.394971            Ilaje
# 31  6.404259       3.295804           Ilashe
# 32  6.553648       3.356674          Ilupeju
# 33  6.613070       3.265907            Ipaja
# 34  6.639043       3.361598           Isheri
# 35  6.535498       3.308678            Isolo
# 36  6.663608       3.669929            Imota
# 37  6.506057       3.331337            Itire
# 38  6.596235       3.391811             Ketu
# 39  6.598781       3.409463           Kosofe
# 40  6.600680       3.383047     Kosofe Ikosi
# 41  6.454900       3.424600     Lagos Island
# 42  6.469800       3.585200            Lekki
# 43  6.617909  400106.000000           Magodo
# 44  6.576421       3.365344         Maryland
# 45  6.535200       3.349000           Mushin
# 46  6.623200       3.346400             Ogba
# 47  6.574900       3.391800            Ogudu
# 48  6.461900       3.157900              Ojo
# 49  6.633700       3.357300            Ojodu
# 50  6.585600       3.381700            Ojota
# 51  6.626300       3.283500          Oke Odo
# 52  6.508800       3.313700            Okota
# 53  6.478000       3.342700            Orile
# 54  6.535500       3.308700           Oshodi
# 55  6.453500       3.626800        Sangotedo
# 56  6.535000       3.389300          Shomolu
# 57  6.492600       3.349000         Surulere
# 58  6.428100       3.421900  Victoria Island
# 59  6.500500       3.366600             Yaba

# %%
high = df[(df['lng'] == 6.4698) | (df['lat'] == 3.5852) | (df['no_bath'] == 1) | (df['no_bed'] == 1) | (df['no_toilets'] == 1) ]['price'].quantile(0.25)

# %%
df['no_toilets'] = df['no_toilets'].astype('int')
df['no_bath'] = df['no_toilets'].astype('int')
df['no_bed'] = df['no_toilets'].astype('int')

# %%
df.to_csv("./data.csv")

# %%
high
# Out:
# 290000.0

# %%
cdf = pd.read_csv('./data.csv')

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13172 entries, 0 to 13171
# Data columns (total 7 columns):
# Unnamed: 0    13172 non-null int64
# lat           13172 non-null float64
# lng           13172 non-null float64
# no_bath       13172 non-null int64
# no_bed        13172 non-null int64
# no_toilets    13172 non-null int64
# price         13172 non-null int64
# dtypes: float64(2), int64(5)
# memory usage: 720.4 KB
